# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# Sample text data (You can use larger datasets)
data = """Shall I compare thee to a summer's day?
Thou art more lovely and more temperate.
Rough winds do shake the darling buds of May,
And summer’s lease hath all too short a date."""

# Tokenize text
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
total_words = len(tokenizer.word_index) + 1  # Vocabulary size

# Convert text into sequences of words
input_sequences = []
words = data.split()
for i in range(1, len(words)):
    n_gram_sequence = words[:i+1]  # Create sequences of increasing length
    token_list = tokenizer.texts_to_sequences([" ".join(n_gram_sequence)])[0]
    input_sequences.append(token_list)

# Pad sequences to equal length
max_seq_length = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_length, padding='pre')

# Create input (X) and output (y) data
X = input_sequences[:, :-1]  # All words except the last one
y = input_sequences[:, -1]   # The last word is the target
y = to_categorical(y, num_classes=total_words)  # One-hot encoding

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Define LSTM Model
model = Sequential([
    Embedding(total_words, 10, input_length=max_seq_length-1),
    LSTM(100, return_sequences=True),
    LSTM(100),
    Dense(total_words, activation='softmax')
])

# Compile Model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# c:\Users\padma\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.fit(X, y, epochs=500, verbose=1)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.0625 - loss: 3.4340
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.0625 - loss: 3.4313
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.0625 - loss: 3.4284
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.0625 - loss: 3.4248
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.0625 - loss: 3.4199
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.0625 - loss: 3.4132
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.0625 - loss: 3.4033
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.0625 - loss: 3.3889
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.0625 - loss: 3.3685
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.0625 - loss: 3.3446
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.0625 - loss: 3.3320
# Epoch 12/500
# ...

# %%
import random

def generate_text(seed_text, next_words=10):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_seq_length-1, padding='pre')
        predicted = np.argmax(model.predict(token_list), axis=-1)
        
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == predicted:
                output_word = word
                break
        seed_text += " " + output_word
    return seed_text

print(generate_text("Shall I compare", next_words=5))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Shall I compare thee to a summer's day
